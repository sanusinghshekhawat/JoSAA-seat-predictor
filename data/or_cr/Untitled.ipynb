# %%
import pandas as pd

# %%
# loading the spreadsheet
lol = pd.read_csv('lol.csv')
df = pd.DataFrame(lol)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12844 entries, 0 to 12843
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Index       12844 non-null  int64
#  1   institute   12835 non-null  object
#  2   branch      12835 non-null  object
#  3   Unnamed: 3  0 non-null      float64
#  4   seat_type   12835 non-null  object
#  5   gender      12355 non-null  object
#  6   or          12150 non-null  float64
#  7   cr          12039 non-null  float64
#  8   year        12844 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 903.2+ KB

# %%
# # Cleaning data:

# # Deleting useless columns like index and unnamed:3
# df = df.drop(df.columns[[0,3]], axis=1)

# # Dropping NA values from institute
# df = df.dropna(thresh = 3)

# df.fillna(0)
# # Converting float values to int
# df['or'] = pd.to_numeric(df['or'], errors='coerce').astype('Int64')
# df['cr'] = pd.to_numeric(df['cr'], errors='coerce').astype('Int64')

# # Selecting Seat_type which are open
# df = df[df['seat_type'] == 'OPEN']

# # Selecting gender which is neutral
# df = df[df['gender'] != 'Female-only (including Supernumerary)']
# df['gender'] = "Neutral"

# #Easiest course to get ie with max cr for every year
max_each_year = df.groupby('year')['cr'].transform('max')
easy_comb = df[df['cr']==max_each_year]
easy_comb.sort_values(by = 'cr', ascending = False)

#Easiest course to get ie with max cr for each institute for a given year
selected_year = int(input("Select a Year from 2016 to 2025:"))
df_selected_year = df[df['year'] == selected_year]
max_selected_year = df_selected_year[df_selected_year['cr']== df_selected_year.groupby('institute')['cr'].transform('max')]
max_selected_year.sort_values(by = 'cr', ascending = False)
# Out:
# Select a Year from 2016 to 2025: 2025
#                                             institute  \
# 12708  Indian Institute  of Technology (BHU) Varanasi
# 12384       Indian Institute  of Technology Kharagpur
# 12838          Indian Institute of Technology Dharwad
# 12684   Indian Institute  of Technology (ISM) Dhanbad
# 12460         Indian Institute  of Technology Jodhpur
# 12820            Indian Institute of Technology Jammu
# 12612         Indian Institute  of Technology Roorkee
# 12302           Indian Institute  of Technology Mandi
# 12774           Indian Institute of Technology Bhilai
# 12556           Indian Institute  of Technology Patna
# 12788        Indian Institute  of Technology Palakkad
# 12800        Indian Institute  of Technology Tirupati
# 12258     Indian Institute  of Technology Bhubaneswar
# 12694           Indian Institute  of Technology Ropar
# 12786              Indian Institute of Technology Goa
# 12336           Indian Institute  of Technology Delhi
# ...
